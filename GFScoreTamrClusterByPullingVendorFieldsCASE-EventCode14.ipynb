# %%
#Scoring by testing various permutations of individual fields
#thought process is the following
#Actor 1 will pull GT7,GT6,GT10,GT16 then 'empty'
#Actor 2 will pull GT7,GT6,GT10,GT16 then 'empty'
#Actor1mention  will pull GT7,GT6,GT10,GT16 then 'empty'
#Actor2mention  will pull GT7,GT6,GT10,GT16 then 'empty'
#Geo we will switch up to try GT10 GT16, GT7, GT6
#Cameo will be GT7,GT16, GT10, GT6
#clustering across cameo codes we need to be careful as to not cross cameos from different types or do we???
#
# 1.) read in all clusters from tamr
# 2.) find how many clusters we have
# 2a.) get distinct clusters
# 3.) start processing each cluster
#   3a.) read in custer[x]
#   3b.) set fields based on rules from above (how we do this)
#   3c.) print out record and where each vaue came from (how do we keep track of where everything came from)
#
#   3d.) score the record
#   3e.) get next cluster

# for i,facts in enumerator(clusters):
#  if facts[i][8] == 'gt7' && facts[i][8] not empty:
#    actor1 = facts[i][2]  <--- get actor1 from gt7 record
# otherwise we would have to check how many gt7 records exist in cluster and check each of those before moving on
import sys
import os
from munkres import Munkres
import numpy as np
import re
import csv
import itertools

import collections

def reduce_vendordata (vendorlist,actor1_source,actor2_source,actor1mention_source,actor2mention_source,cameocode_source,geofullname_source):
    
    #print 'in vendordata',len(vendorlist)
    #print vendorlist

    while_counter = 0
    vendoractor1 = []
    vendoractor2 = []
    vendoractor1mentions = []
    vendoractor2mentions = []
    vendorfullgeonames = []
    vendorcameocodes = []
    vendorguid = []
    vendorentityid = []
    vendorcluster = []
    vendorglobaleventid = []
    actor_counter = 0
    
    

    while while_counter < len(vendorlist):
        #get all of our values for scoring
    
        if actor1_source == vendorlist[while_counter][29]:
            vendoractor1.append(vendorlist[while_counter][15])
            
        if actor2_source == vendorlist[while_counter][29]:
            vendoractor2.append(vendorlist[while_counter][27])
        if actor1mention_source == vendorlist[while_counter][29]:
            vendoractor1mentions.append(vendorlist[while_counter][14])
        if actor2mention_source == vendorlist[while_counter][29]:
            vendoractor2mentions.append(vendorlist[while_counter][26])
        if geofullname_source == vendorlist[while_counter][29]:
            #print 'geo loop check',vendorlist[while_counter][3]
            vendorfullgeonames.append(vendorlist[while_counter][3])
        if cameocode_source == vendorlist[while_counter][29]:
            vendorcameocodes.append(vendorlist[while_counter][43])
        vendorguid.append(vendorlist[while_counter][57])
        vendorcluster.append(vendorlist[while_counter][69])
        vendorentityid.append(vendorlist[while_counter][0])
        vendorglobaleventid.append(vendorlist[while_counter][47])
            
        #clusterid2 = vendorlist[while_counter][8]
        
        #print 'in flatten clusterid',clusterid2
        while_counter += 1
    

    #lets check our values
    #list(set(gt_guid))
    #filter(None, lstr)
    #we are removing all null entries and duplicates just to get to the bare minimums
    vendoractor1 = filter(None,list(set(vendoractor1)))
    vendoractor2 = filter(None,list(set(vendoractor2)))
    vendoractor1mentions = filter(None,list(set(vendoractor1mentions)))
    vendoractor2mentions = filter(None,list(set(vendoractor2mentions)))
    vendorfullgeonames = filter(None,list(set(vendorfullgeonames)))
    vendorcameocodes = filter(None,list(set(vendorcameocodes)))
    vendorguid = filter(None,list(set(vendorguid)))
    vendorcluster = filter(None,list(set(vendorcluster)))
    vendorentityid = filter(None,list(set(vendorentityid)))
    #vendorglobaleventid = filter(None,list(set(vendorglobaleventid)))
    
    #print 'checking for empty'
    #Now we need to check if values are empty and rebuild with other vendors
    if not vendoractor1:
        #print 'in vendoractor1'

        while actor_counter < len(vendorlist):
        #get all of our values for scoring
            #print 'in actor check'
            if not vendoractor1 and vendorlist[actor_counter][29] == 'GT17':
                vendoractor1.append(vendorlist[actor_counter][15])
                vendoractor1 = filter(None,list(set(vendoractor1)))

            elif  not vendoractor1 and vendorlist[actor_counter][29] == 'aic.gt16':
                    
                vendoractor1.append(vendorlist[actor_counter][15])
                vendoractor1 = filter(None,list(set(vendoractor1)))


            elif not vendoractor1 and vendorlist[actor_counter][29] == 'GT6':
                        
                vendoractor1.append(vendorlist[actor_counter][15])
                vendoractor1 = filter(None,list(set(vendoractor1)))

            elif not vendoractor1 and vendorlist[actor_counter][29] == 'GT5':
                                
                vendoractor1.append(vendorlist[actor_counter][15])
                vendoractor1 = filter(None,list(set(vendoractor1)))

            elif not vendoractor1 and vendorlist[actor_counter][29] == 'GT1':
                                    
                vendoractor1.append(vendorlist[actor_counter][15])
                vendoractor1 = filter(None,list(set(vendoractor1)))


                
            actor_counter += 1    
    #Now we need to check if values are empty and rebuild with other vendors
    if not vendoractor2:
        actor2_counter = 0
        while actor2_counter < len(vendorlist):
        #get all of our values for scoring
    
            if vendorlist[actor2_counter][29] == 'GT17':
                vendoractor2.append(vendorlist[actor2_counter][27])
            
                vendoractor2 = filter(None,list(set(vendoractor2)))
               
            elif  not vendoractor2 and vendorlist[actor2_counter][29] == 'aic.gt16':
                    
                vendoractor2.append(vendorlist[actor2_counter][27])
                vendoractor2 = filter(None,list(set(vendoractor2)))

            elif not vendoractor2 and vendorlist[actor2_counter][29] == 'GT6':
                        
                vendoractor2.append(vendorlist[actor2_counter][27])
                vendoractor2 = filter(None,list(set(vendoractor2)))

            elif not vendoractor2 and vendorlist[actor2_counter][29] == 'GT5':
                                
                vendoractor2.append(vendorlist[actor2_counter][27])
                vendoractor2 = filter(None,list(set(vendoractor2)))


            elif not vendoractor2 and vendorlist[actor2_counter][29] == 'GT1':
                                    
                vendoractor2.append(vendorlist[actor2_counter][27])
                vendoractor2 = filter(None,list(set(vendoractor2)))

                
            actor2_counter += 1   
    if not vendoractor1mentions:
        #print 'in vendoractor1mention'
        actor1m_counter = 0
        while actor1m_counter < len(vendorlist):
        #get all of our values for scoring
    
            if vendorlist[actor1m_counter][29] == 'GT17':
                vendoractor1mentions.append(vendorlist[actor1m_counter][14])
                vendoractor1mentions = filter(None,list(set(vendoractor1mentions)))
               
            elif  not vendoractor1mentions and vendorlist[actor1m_counter][29] == 'aic.gt16':
                    
                vendoractor1mentions.append(vendorlist[actor1m_counter][14])
                vendoractor1mentions = filter(None,list(set(vendoractor1mentions)))

            elif not vendoractor1mentions and vendorlist[actor1m_counter][29] == 'GT6':
                        
                vendoractor1mentions.append(vendorlist[actor1m_counter][14])
                vendoractor1mentions = filter(None,list(set(vendoractor1mentions)))

            elif not vendoractor1mentions and vendorlist[actor1m_counter][29] == 'GT5':
                                
                vendoractor1mentions.append(vendorlist[actor1m_counter][14])
                vendoractor1mentions = filter(None,list(set(vendoractor1mentions)))


            elif not vendoractor1mentions and vendorlist[actor1m_counter][29] == 'GT1':
                                    
                vendoractor1mentions.append(vendorlist[actor1m_counter][14])
                vendoractor1mentions = filter(None,list(set(vendoractor1mentions)))
           
            actor1m_counter += 1 
            
    if not vendoractor2mentions:
        #print 'in vendoractor2mention'
        actor2m_counter = 0
        while actor2m_counter < len(vendorlist):
        #get all of our values for scoring
    
            if vendorlist[actor2m_counter][29] == 'GT17':
                vendoractor2mentions.append(vendorlist[actor2m_counter][26])
                vendoractor2mentions = filter(None,list(set(vendoractor2mentions)))
            
            elif  not vendoractor2mentions and vendorlist[actor2m_counter][29] == 'aic.gt16':
                    
                vendoractor2mentions.append(vendorlist[actor2m_counter][26])
                vendoractor2mentions = filter(None,list(set(vendoractor2mentions)))

            elif not vendoractor2mentions and vendorlist[actor2m_counter][29] == 'GT6':
                        
                vendoractor2mentions.append(vendorlist[actor2m_counter][26])
                vendoractor2mentions = filter(None,list(set(vendoractor2mentions)))

            elif not vendoractor2mentions and vendorlist[actor2m_counter][29] == 'GT5':
                                
                vendoractor2mentions.append(vendorlist[actor2m_counter][26])
                vendoractor2mentions = filter(None,list(set(vendoractor2mentions)))


            elif not vendoractor2mentions and vendorlist[actor2m_counter][29] == 'GT1':
                                    
                vendoractor2mentions.append(vendorlist[actor2m_counter][26])
                vendoractor2mentions = filter(None,list(set(vendoractor2mentions)))

               
            actor2m_counter += 1 
    if not vendorfullgeonames:
        #print 'in vendorfullgeonames'
        geo_counter = 0
        while geo_counter < len(vendorlist):
        #get all of our values for scoring
    
            if vendorlist[geo_counter][29] == 'GT17':
                vendorfullgeonames.append(vendorlist[geo_counter][3])

                vendorfullgeonames = filter(None,list(set(vendorfullgeonames)))
               
            elif  not vendorfullgeonames and vendorlist[geo_counter][29] == 'aic.gt16':
                    
                vendorfullgeonames.append(vendorlist[geo_counter][3])
                vendorfullgeonames = filter(None,list(set(vendorfullgeonames)))

            elif not vendorfullgeonames and vendorlist[geo_counter][29] == 'GT6':
                        
                vendorfullgeonames.append(vendorlist[geo_counter][3])
                vendorfullgeonames = filter(None,list(set(vendorfullgeonames)))

            elif not vendorfullgeonames and vendorlist[geo_counter][29] == 'GT5':
                                
                vendorfullgeonames.append(vendorlist[geo_counter][3])
                vendorfullgeonames = filter(None,list(set(vendorfullgeonames)))


            elif not vendorfullgeonames and vendorlist[geo_counter][29] == 'GT1':
                                    
                vendorfullgeonames.append(vendorlist[geo_counter][3])
                vendorfullgeonames = filter(None,list(set(vendorfullgeonames)))             
                
            geo_counter += 1
    if not vendorcameocodes:
        #print 'in vendorcameocodes'
        cameo_counter = 0
        while cameo_counter < len(vendorlist):
        #get all of our values for scoring
    
            if vendorlist[cameo_counter][29] == 'GT17':
                vendorcameocodes.append(vendorlist[cameo_counter][43])
                vendorcameocodes = filter(None,list(set(vendorcameocodes)))
               
            elif  not vendorcameocodes and vendorlist[cameo_counter][29] == 'aic.gt16':
                    
                vendorcameocodes.append(vendorlist[cameo_counter][43])
                vendorcameocodes = filter(None,list(set(vendorcameocodes)))

            elif not vendorcameocodes and vendorlist[cameo_counter][29] == 'GT6':
                        
                vendorcameocodes.append(vendorlist[cameo_counter][43])
                vendorcameocodes = filter(None,list(set(vendorcameocodes)))

            elif not vendorcameocodes and vendorlist[cameo_counter][29] == 'GT5':
                                
                vendorcameocodes.append(vendorlist[cameo_counter][43])
                vendorcameocodes = filter(None,list(set(vendorcameocodes)))


            elif not vendorcameocodes and vendorlist[cameo_counter][29] == 'GT1':
                                    
                vendorcameocodes.append(vendorlist[cameo_counter][43])
                vendorcameocodes = filter(None,list(set(vendorcameocodes)))
   
            cameo_counter += 1
    

    #if '2500611' in vendorcluster:
        #print 'vendorlist',vendorlist
        #print 'a1',vendoractor1
        #print 'a2',vendoractor2
 
    
    '''
    print 'a1',vendoractor1
    print 'a2',vendoractor2
    print 'a1m',vendoractor1mentions
    print 'a2m',vendoractor2mentions
    print 'fgn',vendorfullgeonames
    print 'cameo',vendorcameocodes
    print 'guid',vendorguid
    #print 'id',vendorid
    #print clusterid
    '''
    return vendoractor1,vendoractor2,vendoractor1mentions,vendoractor2mentions,vendorfullgeonames,vendorcameocodes,vendorguid,vendorcluster,vendorentityid
    #end of vendor data function



class Vendor_Data(object):
    def __init__(self,data,pointer):
        #self.globaleventid = data[pointer][0]
        
        #print 'in vendor event_data and global_eventid = ',self.globaleventid
        
        self.actor1name = data[pointer][0]
        self.actor2name = data[pointer][1]
        self.actor1mention = data[pointer][2]
        self.actor2mention = data[pointer][3]
        self.actiongeo_fullname = data[pointer][4]
        self.eventcode = data[pointer][5]
        self.guid = data[pointer][6]
        #self.cluster = data[pointer][7]
        
class GroundTruth_Data(object):
    def __init__(self,data,pointer):
        self.globaleventid = data[pointer][0]
        
        #print 'in ground truth event_data and global_eventid = ',self.globaleventid
        
        self.actor1name = data[pointer][1]
        self.actor2name = data[pointer][2]
        self.actor1mention = data[pointer][3]
        self.actor2mention = data[pointer][4]
        self.actiongeo_fullname = data[pointer][5]
        self.eventcode = data[pointer][6]
        self.guid = data[pointer][7]

def compute_score(true_event, test_event):
    
	#print 'in compute_score check our gt values',true_event.actor1name
	#print 'in compute_score check our vendor values',test_event.actor1name
	# """
	# Evaluate the score of test event
	# parameters:
	#    true_event: json 
	#    test_event: json
	# """
	################
	# score actor1 #
	################
	# only evaluate the actor1name with true event using partial match
	actor1_score = 0.0
	test_actor1 = test_event.actor1name
	#print 'print vendor actor1',test_actor1    
	# if there are multiple sources, we match the actor1 with 
	# highest score. In Reciproal case, we compare the actor1/2 with 
	# the same set of Reciprocal texts.
	if true_event.actor1name:
		sources = true_event.actor1name.split(";")
	else:
		sources = []
	if true_event.actor1mention:
		new_sources = true_event.actor1mention.split(";")
		for new_source in new_sources:
			sources.append(new_source)
	#print 'here'
	act_score = 0.
	for source in sources:
		act_score = 3.0 if text_partial_match(source, test_actor1) else 0.
		if act_score > actor1_score:
			actor1_score = act_score
	#print 'actor1 score',act_score
	################
	# score actor2 #
	################
	actor2_score = 0.0
	test_actor2 = test_event.actor2name
	#print 'print vendor actor2',test_actor2
    
	if true_event.actor2name:
		targets = true_event.actor2name.split(";")
	else:
		targets = []
	if true_event.actor2mention:
		new_targets = true_event.actor2mention.split(";")
		for new_target in new_targets:
			targets.append(new_target)

	for target in targets:
		#print 'in targets',target    
		actor_score = 3.0 if text_partial_match(target, test_actor2) else 0
		#print 'actor2 score',actor_score
		if act_score > actor2_score:
			actor2_score = act_score

	##################
	# Score Location #
	##################
	# Match Location with partial match
	location_score = 0.0
	true_location = true_event.actiongeo_fullname.split(";")
	test_location = test_event.actiongeo_fullname.strip()
	#print 'print gt location',true_location    
	#print 'print vendor location',test_location
	if len(true_location) == 0:
		if test_location == "":
			location_score = 3.0
		else:
			location_score = 0.0
	else:
		for loc in true_location:
			tem_score = 3.0 if text_partial_match(loc, test_location) else 0.0
			if tem_score > location_score:
				location_score = tem_score
    
	################
	# score action #
	################
	# compute the action score with two level: root and subtype
	action_score = 0.0
	#print 'event code check',test_event.eventcode    
	true_code = true_event.eventcode.split(" ")[0]
	test_code = test_event.eventcode.split(" ")[0]
    
	#print 'checking our event code values for gt -->',true_code
	#print 'checking our test code values for gt -->',test_code
    
	if test_code is None or len(test_code) < 2:
		#print 'in action score fail'        
		action_score = 0.0
	else:
		if true_code[:2] == test_code[:2]:
			#print 'checking action score',true_code[:2],test_code[:2],action_score
			action_score += 2.0
			if len(test_code) > 3 and test_code[2] == true_code[2]:
				action_score += 1.0
    
	###############
	# Date Score ##
	###############
	# since the Date field in the GSR is not normalized, we don't compute the
	# score here
	date_score = 0.0

	final_score = [actor1_score, actor2_score, location_score, action_score, date_score]

    
	fields = ["Actor1", "Actor2", "Location", "Action", "Date"]
	#print 'Final_Score -->',sum(final_score),dict(zip(fields, final_score))

	return sum(final_score), dict(zip(fields, final_score))

def text_partial_match(true_text, test_text):
	"""
	partial match the true_text and test_text based on following step
	1> transform the text to lowercase 
	2> split the text by space or comma and ignore ''
	3> if any pair of elements from two different text arraies equal to each
	other, return True else False
	"""
	true_text_splits = set([r for r in re.split(r" |,", true_text.lower()) if r != ''])
	test_text_splits = set([r for r in re.split(r" |,", test_text.lower()) if r != ''])
    
	if true_text_splits.intersection(test_text_splits):
		return True
	else:
		return False
        
        
        
def global_match(ground_truth, vendor_events):
    """
    matching the true events with test events with global optimal score
    """
    
    gt_guid = []    
    vendor_guid = []
    vendor_score = 0.00
    
    for records, true_event in enumerate(ground_truth):
        #if records == len(ground_truth): break        
        #extract guid

        #print records        
        gt_guid.append(ground_truth[records][7])

    #print 'vendor_events',vendor_events
    for counter, records in enumerate(vendor_events):
        #extract guid
        #print records
        vendor_guid.append(vendor_events[counter][6])
    
    gtguids = list(set(gt_guid))

    #print 'here is my gt set', len(gtguids)
    
    vendorguid = list(set(vendor_guid))
    #print 'here is my vendor set', len(vendorguid)
    
    #let's check how many values are in our vendor set
    guids_to_process = []    
    for guids,groundtruth in enumerate(gtguids):
        #print 'checking',gt         
        if gtguids[guids] in vendorguid:
            guids_to_process.append(gtguids[guids])  
    #print 'here are my guids_to_process',guids_to_process 

    #ok, so now lets iterate through out guids
    #print 'before guid count'
    #open our file to write our results out to

    #score_matrix = []        
    for processing in guids_to_process:
        #print 'processing guids'
        vendor_1 = filter(lambda vendor_events: vendor_events[6] in processing, vendor_events) 
        gt_1  = filter(lambda ground_truth: ground_truth[7] in processing, ground_truth)        
        
        
        score_matrix = np.zeros((len(gt_1),len(vendor_1)))  
        #print 'vendor length',vendor_1
        #print 'gt length',gt_1
        
        score_detail = {}
        for i, true_event in enumerate(gt_1):
            #print 'loop counter',i
            true_events = GroundTruth_Data(gt_1,i)

            for j, test_event in enumerate(vendor_1):   
    
                test_events = Vendor_Data(vendor_1,j)    
                
                score, score_list = compute_score(true_events, test_events)
                #print 'score on return',score                
                if score > 0:
                    #print 'here is the score for guid:',processing,score            
                    score_matrix[i, j] = score
                    score_detail[(i,j)] = {"score": score, "detail": score_list, "pair": [test_event]} 
                #if processing == '0070cb46-4a4e-4964-8904-6283bd1c34e0' and score >0:
                    #print 'processing',processing,score,score_list,test_event 
                    
                    
                
        cost_matrix = 10000 - score_matrix
        m = Munkres()

        #print 'after munkres'
        indexes = m.compute(cost_matrix.tolist())
        #print 'here are my indexes',indexes
        total_score = sum(score_matrix[zip(*indexes)])
        #print 'total_score',total_score
        event_pairs = []
        #going to track total score 
        #print 'the total score field is',total_score
        vendor_score += total_score        
        print 'The total score for guid %s is: %s'%(processing,total_score) 
        unmatched_events = []
        spurious_events = []
        #matched_true_ids, matched_test_ids = zip(*indexes)
        #print matched_true_ids

        #if processing =='6b4f7c60-1141-4259-b551-15ebb0b88b84':
        #print 'processing our test guid',processing
        #print 'score',vendor_score
           

        
    return vendor_score     


# function to build our record to score
def buildrecord(tamr_records,actor1_source,actor2_source,actor1mention_source,actor2mention_source,cameocode_source,geofullname_source):

    actor1_from = actor1_source
    actor2_from = actor2_source
    actor1mention_from = actor1mention_source
    actor2mention_from = actor2mention_source
    cameocode_from = cameocode_source
    geofullname_from = geofullname_source
    vendor_matrix = None
    
    #print 'tamr_records in buildrecord',tamr_records   
    #check how many instances of each vendor type we have
    #gt7_count = sum(x.count('gt7') for x in tamr_records)
    #gt16_count = sum(x.count('aic.gt16') for x in tamr_records)
    #gt10_count = sum(x.count('gt10') for x in tamr_records)
    #gt6_count = sum(x.count('gt6') for x in tamr_records)
    
    
    #print 'in build record'

    #print 'gt7',gt7_count
    #print 'gt16',gt16_count
    #print 'gt10',gt10_count
    #print 'gt6',gt6_count
    
    #print 'actor1source',actor1_source
    #print 'actor2source',actor2_source
    #print 'geofull',geofullname_source
    
    #print 'len of tamr_records',len(tamr_records)
    
    vendoractor1,vendoractor2,vendoractor1mentions,vendoractor2mentions,vendorfullgeonames,vendorcameocodes,vendorguids,vendorcluster,vendorentityid = reduce_vendordata(tamr_records,actor1_source,actor2_source,actor1mention_source,actor2mention_source,cameocode_source,geofullname_source)



    
    if not vendoractor1:
        vendoractor1.append('EMPTY')
    if not vendoractor2:
        vendoractor2.append('EMPTY')
    if not vendoractor1mentions:
        vendoractor1mentions.append('EMPTY')
    if not vendoractor2mentions:
        vendoractor2mentions.append('EMPTY')
    if not vendorfullgeonames:
        vendorfullgeonames.append('EMPTY')
    if not vendorcameocodes:
        vendorcameocodes.append('EMPTY')
    if not vendorguids:
        vendorguids.append('EMPTY')
    #print 'before matrix build'
    #if vendoractor1[0]=='EMPTY'and vendoractor2[0]=='EMPTY'and vendoractor1mentions == 'EMPTY'and vendoractor2mentions =='EMPTY' and vendorcameocodes == 'EMPTY':
    vendor_matrix = list(itertools.product(vendoractor1,vendoractor2,vendoractor1mentions,vendoractor2mentions,vendorfullgeonames,vendorcameocodes,vendorguids,vendorcluster))
    #vendor_matrix = (list(tup) for tup in itertools.product(vendoractor1,vendoractor2,vendoractor1mentions,vendoractor2mentions,vendorfullgeonames,vendorcameocodes,vendorguids,vendorcluster))
    
                   
    
    if '07da045f-fca3-4cc7-b9b4-3e448a2edc72' in vendorguids:
    
        print vendor_matrix
    if '77fa5ad0-0d3e-4828-a9f7-d396574f4e77' in vendorguids:
        print vendor_matrix

    if 'a0b1b986-8bf9-422f-bf0b-e6ab6c1b9905' in vendorguids:
        print vendor_matrix
 
        
    #if vendorguids[0]== '6b4f7c60-1141-4259-b551-15ebb0b88b84':
        #print vendor_matrix
    #writer = csv.writer(open("/Users/Pete/July25FlattenclusterGT7.csv",'a'))
    #writer.writerow([vendor_matrix])    
      
    #record_to_score = []
    #record_to_score.extend([actor1pulled,actor2pulled,actor1mentionpulled,actor2mentionpulled,cameocodepulled,geofullnamepulled,guidpulled,actor1_from,actor2_from,actor1mention_from,actor2mention_from,cameocode_from,geofullname_from])
    
    #print 'record to score',vendor_matrix
    
    #print actor1,actor2,actor1mention,actor2mention,cameocode,geofullname,actor1_from,actor2_from,actor1mention_from,actor2mention_from,cameocode_from,geofullname_from
     
    #return str(record_to_score).replace('[','').replace(']','')
    return vendor_matrix,vendorentityid[0]


#****************
#main body of program
#****************


actor1_processing = raw_input('Which Actor1 vendor should we score on? ')
actor2_processing = raw_input('Which Actor2 vendor should we score on? ')
actor1mention_processing = raw_input('Which Actor1Mention vendor should we score on? ')
actor2mention_processing = raw_input('Which Actor2 Mention vendor should we score on? ')
cameocode_processing = raw_input('Which Cameo code vendor should we score on? ')
geofullname_processing = raw_input('Which GeoFullName vendor should we score on? ')
cluster_total_score = 0.00
vendorscore=0.00

#read in tamr data
#tamr_data = '/Users/Pete/Customers/2016.Feb Greenfield/onefulltamrrecord.csv'
tamr_data ='/Users/Pete/tamrclustersAug3run1.csv'
#tamr_data = '/Users/Pete/Customers/OneGuidGT7.csv'

with open(tamr_data, 'rU') as f:  #opens PW file
    reader = csv.reader(f)
    tamrds = list(list(rec) for rec in csv.reader(f, delimiter=',')) #reads csv into a list of lists

#read in ground truth data
gt_data = '/Users/Pete/Customers/2016.Feb Greenfield/July20ScoringRun/groundtruthcombined.score.csv'

with open(gt_data, 'rU') as f:  #opens PW file
    reader = csv.reader(f)
    dsgold = list(list(rec) for rec in csv.reader(f, delimiter=',')) #reads csv into a list of lists


clusters_to_process = []
a=[]
#get all the clusters
for counter,clusters in enumerate(tamrds):
    clusters_to_process.append(tamrds[counter][69])
    
clusters = list(set(clusters_to_process))    

#print 'our unique cluster ids',len(clusters)

#uncomment to write out for delivery
fp = open("/Users/Pete/Aug3GT11CameoCode14.csv",'a')

output = csv.writer(fp)

for count,elements in enumerate(clusters):
    
    #if count % 1000 == 0:
        #print 'processing on count',count
    dstamr_clusters = filter(lambda tamrds: tamrds[69] in elements,tamrds)
    

    #call function to build record to score from our cluster
    tamr_record_to_score,vendorentityid = buildrecord(dstamr_clusters,actor1_processing,actor2_processing,actor1mention_processing,actor2mention_processing,cameocode_processing,geofullname_processing)
    #if count % 300 == 0:
        #print 'tamr_record_check',tamr_record_to_score
    #uncomment for writeout to delivery
    outputrow =[x for t in tamr_record_to_score for x in t] 
    outputrow.append(vendorentityid) 
    output.writerow(outputrow)
    if tamr_record_to_score != None:
        a.extend(tamr_record_to_score)
fp.close()
#print 'record to score',a
#print 'works',tamr_record_to_score
#print "length of a",a
#print 'after matrix build'
#writer.writerow(a) 
    #wr.writerow(tamr_record_to_score)
#print 'moving onto scoring'
#print 'length of a',len(a)

vendorscore = global_match(dsgold,a)

#vendorscore +=cluster_total_score
       
#if cluster_total_score > 0:
    #print 'using input from sources %s the score for is %s'%(actor1_processing,cluster_total_score)
    #print cluster_total_score
#cluster_total_score = cluster_total_score + cluster_total_score
    
print 'Total for this vendor',vendorscore

print 'fini'
# Out:
# Which Actor1 vendor should we score on? GT7
# Which Actor2 vendor should we score on? GT7
# Which Actor1Mention vendor should we score on? GT7
# Which Actor2 Mention vendor should we score on? GT7
# Which Cameo code vendor should we score on? GT7
# Which GeoFullName vendor should we score on? GT7
# [('EMPTY', 'against the U.N. Security Council\xe2\x80\x99s condemnation of its test-firing of ballistic missiles', 'EMPTY', 'against the U.N. Security Council\xe2\x80\x99s condemnation of its test-firing of ballistic missiles', 'Pyongyang', '140: CivilUnrest Nonviolent', 'a0b1b986-8bf9-422f-bf0b-e6ab6c1b9905', '2500013')]
# [('Viktor Yanukovych', 'against his government', 'Yanukovych', 'against his government', 'Ukraine', '140: CivilUnrest Nonviolent', '07da045f-fca3-4cc7-b9b4-3e448a2edc72', '2500612')]
# [('Yanukovych', 'government;street', 'Yanukovych', 'government', 'U.S.', '140: CivilUnrest Nonviolent', '07da045f-fca3-4cc7-b9b4-3e448a2edc72', '2500611')]
# [('EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'his government', '140: CivilUnrest Nonviolent', '07da045f-fca3-4cc7-b9b4-3e448a2edc72', '2500610')]
# [('EMPTY', 'center', 'EMPTY', 'center', 'Ukraine', '140: CivilUnrest Nonviolent', '77fa5ad0-0d3e-4828-a9f7-d396574f4e77', '2500008')]
# [('EMPTY', 'EMPTY', 'EMPTY', 'EMPTY', 'Ukraine', '140: CivilUnrest Nonviolent', '07da045f-fca3-4cc7-b9b4-3e448a2edc72', '2500609')]
# The total score for guid 825b189d-9f18-4fd4-8cdc-a698afb14c69 is: 0.0
# The total score for guid ccda9cc8-bd9b-4317-978c-1582f41d3498 is: 0.0
# The total score for guid 7e1e8bc4-f58f-4043-87d2-81b5a4293e67 is: 5.0
# The total score for guid 82af1c43-9573-44d6-8a28-296f481a6006 is: 2.0
# The total score for guid cbb5ac42-18f1-406d-ac6a-7e6e97cf1663 is: 0.0
# The total score for guid 965e0493-31f0-4e8f-88c4-75d057b3eebf is: 3.0
# The total score for guid 0e996f08-5506-42bc-afc2-22c03f0f28c5 is: 0.0
# The total score for guid 7503fceb-78ef-478f-94f8-2efd077bc0e3 is: 0.0
# The total score for guid 630d1492-91c7-411c-91b1-2542e1bfa368 is: 3.0
# The total score for guid 7ce6f194-6081-4f0c-b88b-f47e04c01d33 is: 0.0
# The total score for guid 2d38c42b-33f5-4153-97a4-73f45ff99c86 is: 0.0
# The total score for guid c08a8d6d-621c-407b-9131-42ef38845b10 is: 0.0
# The total score for guid a634c9bf-bcbe-408b-a497-796441b65294 is: 0.0
# The total score for guid 2da2c1c0-1d11-470b-b10e-f9caea8e4914 is: 5.0
# The total score for guid 9ad50f5c-b9cd-4709-b66b-47260e14ecd3 is: 0.0
# The total score for guid fcdc1f2b-37e2-4aa7-91db-301b8231e68d is: 0.0
# The total score for guid cb01c2e7-5cc0-4cf9-b19d-c1de6d8b6cf3 is: 0.0
# The total score for guid 8c1f7823-ae08-45f9-980d-4eaa9ccda94f is: 0.0
# The total score for guid 8d47a97f-08a7-4b16-b680-7bd5e9a7749b is: 0.0
# The total score for guid 78ccdf54-b6c4-41c3-b03e-8985a0c7c8be is: 0.0
# The total score for guid 66b1144b-1d87-4db1-b436-5087c604baaa is: 3.0
# The total score for guid b4b71156-8603-4553-961c-835b943f865d is: 2.0
# The total score for guid e38fdfe3-30b7-4077-939b-332aa2f9773c is: 0.0
# The total score for guid 890000ce-2b9b-49d9-9023-967d57f8a65f is: 0.0
# The total score for guid 2a0ac5e1-2899-44de-bceb-4ef5097a70ed is: 0.0
# The total score for guid dfb4e160-ff9b-4513-8ba4-9926b0a1040a is: 0.0
# The total score for guid ede1d199-2790-4d3e-a736-95e7f72b461a is: 0.0
# The total score for guid 7b343218-b2d3-4b60-8696-a9a555313630 is: 0.0
# The total score for guid 0b0c5ed5-48db-43f9-8d52-47c7c9729d06 is: 0.0
# The total score for guid a2096153-dcfe-4676-81a8-0bc3d38c4b3c is: 0.0
# The total score for guid 67dcf07a-b671-4aa4-a25d-a75c62ce80fb is: 0.0
# The total score for guid 0c0f1c7d-bb89-4c0c-9262-ff0f98b69e0d is: 0.0
# The total score for guid d1d52912-f38b-4c18-88df-14e6e0056044 is: 0.0
# The total score for guid 6992fa66-e04d-470c-92e4-cc765ee6fa81 is: 0.0
# The total score for guid 4074f762-d9b6-4edb-9b46-219f117eeb07 is: 0.0
# The total score for guid b589ae7e-859b-42ea-bab7-91bd2922e5dd is: 0.0
# The total score for guid 72b90d52-5b2e-4976-8963-19a89606eb5e is: 0.0
# The total score for guid 6b1bd8c5-1344-44b2-85f8-b6f48d6f9b39 is: 0.0
# The total score for guid 01439f66-56a7-47ef-b3ec-a1cec5077686 is: 11.0
# The total score for guid 04ec174c-748f-4965-9cde-2a13069cffeb is: 3.0
# The total score for guid 3ee330a9-1530-4882-a8c1-ee6bb6512e1e is: 0.0
# The total score for guid 7256ab17-5d1d-4c63-b18d-1fe3879bc38d is: 0.0
# The total score for guid 4a6f7d79-9698-4df8-900d-790f902581d9 is: 0.0
# The total score for guid f6f9be49-ff32-4ad0-b1a9-2c83734626b8 is: 5.0
# The total score for guid 2956b671-7a0f-4d56-b765-6ab9c78e5c34 is: 0.0
# The total score for guid 2cf9b7c3-d3be-4429-9d66-f3257e924991 is: 0.0
# The total score for guid 8a115d5d-c59e-4d94-b5c1-a502da0cc6f5 is: 0.0
# The total score for guid 3ed8f0c4-68df-42f1-831a-9aafc7bc7c68 is: 0.0
# The total score for guid 5076e267-3b4c-4776-b9e5-114873778d40 is: 0.0
# The total score for guid 2fbf1c46-fbd2-4fe8-9f5a-7d37e9763af8 is: 0.0
# The total score for guid bf90dbff-ef9c-47cd-bce7-f9f2362bb037 is: 0.0
# The total score for guid e18adbb7-ddb2-48d3-abad-536c0a4ba02d is: 6.0
# The total score for guid 38b98a17-17cf-4d74-96db-8133fb431392 is: 0.0
# The total score for guid 4685ca47-f138-4839-8eed-2e14c7044719 is: 0.0
# The total score for guid 356c1635-092c-4a53-8623-fb6f676e52bc is: 3.0
# The total score for guid ad2cac84-3c91-441e-bd36-48918817b983 is: 0.0
# The total score for guid 1637e26b-07fe-40dd-a97b-4cc7bcbd9efc is: 0.0
# The total score for guid ab161f08-4c3a-4a10-ba92-c93f813c4e61 is: 9.0
# The total score for guid 225426a2-2e3c-4231-8038-7de0992060a3 is: 0.0
# The total score for guid 5b707226-9b87-48a6-b000-61257da76558 is: 0.0
# The total score for guid eb03a613-bee1-4f71-9a42-5ad68a0e1820 is: 9.0
# The total score for guid 3d2216c3-b1cc-4c53-83e8-41d662844eb8 is: 0.0
# The total score for guid fb6750f7-da0d-4b3e-947d-49eb96304932 is: 0.0
# The total score for guid 36eaa542-3c01-4464-a196-ae62c9b93b43 is: 0.0
# The total score for guid 504ee018-af82-4ef4-ae0f-ab98b192a982 is: 0.0
# The total score for guid faf71b4a-5968-4cc5-b2d2-1327fe3f30a6 is: 0.0
# The total score for guid 63b544bd-cdc2-419b-a473-cc1ba77702bc is: 0.0
# The total score for guid bc2f8040-aefd-4991-9c09-719288d6cd01 is: 0.0
# The total score for guid 77e1a36a-fbb7-4fbc-99ca-320695c7c6e4 is: 26.0
# The total score for guid edf4a4e8-2ef6-45ae-b0b7-b89d79b8981a is: 3.0
# The total score for guid e40f6592-f1dc-47e2-99e6-53c337826646 is: 0.0
# The total score for guid a07a20b2-ffcc-4a03-9d9c-17eb67b03b65 is: 0.0
# The total score for guid 108a9a8b-e363-4882-914a-7505f22120ac is: 22.0
# The total score for guid 7fd16014-bfc1-4240-a5fd-c3f24d0c1cb4 is: 0.0
# The total score for guid 43602c46-9c49-4390-9527-89c7e031c236 is: 0.0
# The total score for guid 2185f5ac-b000-4c3e-a82a-0e2a77ae003c is: 0.0
# The total score for guid 7b038b1d-1a20-4e81-9f3c-1a3657ac6efc is: 6.0
# The total score for guid 17443185-6ada-455e-8a57-727aa08d5412 is: 0.0
# The total score for guid 5a3ad533-493e-42db-ad20-f92e5d0c162f is: 0.0
# The total score for guid c1c67f7e-6c5e-435c-a8c6-0f5f768763be is: 3.0
# The total score for guid bda2b41a-f35f-4403-91a8-1594d91fdbe5 is: 0.0
# The total score for guid a798170a-f05c-49ec-8033-b4eb02c03535 is: 0.0
# The total score for guid d877aa61-7e8c-4e4a-ba23-9ee0e002a158 is: 0.0
# The total score for guid 3e384c41-2a0d-47d0-b2bf-2e7c93f8b3b2 is: 0.0
# The total score for guid 60182338-a053-4a2d-806c-5abc5e798d06 is: 0.0
# The total score for guid e46b8eb3-4333-4855-b8f6-950ff51d56c1 is: 0.0
# The total score for guid 0265ce4c-9679-4cec-b7e0-d7b874080d0c is: 2.0
# The total score for guid 040a5a26-c2c7-4892-880f-2cf2283006fd is: 12.0
# The total score for guid acb6d139-ec25-46ab-a7b1-fca38fc78125 is: 6.0
# The total score for guid e21132c4-ba1d-4ba0-8ea1-2331224dfe96 is: 0.0
# The total score for guid 2ab10d31-640d-40f7-ba6c-489f3d7b58a4 is: 0.0
# The total score for guid efcb8902-698c-434f-ac0a-f648b34755ab is: 24.0
# The total score for guid 07da045f-fca3-4cc7-b9b4-3e448a2edc72 is: 18.0
# The total score for guid 70ccd432-367a-4f32-9931-3c612143b7c0 is: 0.0
# The total score for guid 118c1371-71e1-44b5-860d-274785b92474 is: 2.0
# The total score for guid 2a90f1d7-81aa-48b8-b0f4-b04b97c131c0 is: 7.0
# The total score for guid 522455b7-8eda-47e8-b444-98a1f93f19d2 is: 0.0
# The total score for guid 7d11c02e-fdf2-412c-97d0-e7acbf623011 is: 0.0
# The total score for guid f37ab6cc-0a84-447b-8d30-4dd51e404cc2 is: 0.0
# The total score for guid 4adb31c1-8047-40ee-a513-8600671b96a8 is: 4.0
# The total score for guid 9bed300c-736c-4fda-a4a0-3d29f2d58475 is: 7.0
# The total score for guid 43b723e5-5db3-4829-9ceb-e556d499d9f7 is: 0.0
# The total score for guid 2fd37601-4ec5-4527-9287-2ccce6e40ab1 is: 0.0
# The total score for guid f24acd13-cbae-4133-a7cb-2412c2155250 is: 0.0
# The total score for guid 12c9db41-c8fa-45bb-a165-0a873202d9ca is: 0.0
# The total score for guid b3a3e689-52a4-46ee-acb4-3fd51358eaa3 is: 0.0
# The total score for guid ef964624-8922-4f35-9268-ef58e7088de0 is: 0.0
# The total score for guid bfa8f313-baeb-4134-bcbe-a80910517de5 is: 0.0
# The total score for guid da95148c-b8cd-4b99-9710-5f38c609581f is: 6.0
# The total score for guid 748f137b-7711-49cc-990b-827342c56504 is: 0.0
# The total score for guid 87748a9b-7c7f-4198-946f-e44da16b74ec is: 0.0
# The total score for guid 6cbb3d87-fc92-4012-ba44-1df8c173aad0 is: 0.0
# The total score for guid 3e7d452c-3808-4e44-8f51-3143914ea3a8 is: 0.0
# The total score for guid 2e5a830d-7586-4c7d-90ba-051f90bc3441 is: 2.0
# The total score for guid 4681b904-973f-4a9e-8689-1a273dab6632 is: 0.0
# The total score for guid d6df2102-76cd-4ced-9a25-7e941ff18562 is: 5.0
# The total score for guid 5aaf37bf-4a7e-43e1-9551-8da30e31ef22 is: 2.0
# The total score for guid 2ecacb58-023a-4ea8-b0ad-47a719514c3c is: 0.0
# The total score for guid ce958306-0084-4c74-965b-003b80ce2754 is: 0.0
# The total score for guid d1ef97d0-2bb9-494c-9d84-18dcbd7a6d5c is: 9.0
# The total score for guid eae356ba-0977-41f0-a1e8-dcd11092c688 is: 0.0
# The total score for guid 9b59e528-3211-4ba8-a48c-2ae913bceeeb is: 0.0
# The total score for guid 138cd742-be73-403d-818a-a4e7f51c54f5 is: 2.0
# The total score for guid 362a73c9-ef78-422e-a964-84d24389154a is: 0.0
# The total score for guid 2ed92a3f-6d8d-4d3b-b10b-d65285c5ab8b is: 0.0
# The total score for guid 19c337a6-a46c-40cf-82ae-d1f9072ac245 is: 0.0
# The total score for guid 2aeccd0f-49d2-4465-adde-0d84edb7a273 is: 6.0
# The total score for guid 2fd63128-e4d7-4fe3-b9dd-3207c31caddf is: 0.0
# The total score for guid 28037c64-ff74-49fb-9fd4-17c062a1a804 is: 6.0
# The total score for guid e8e4b3d7-a025-4241-b733-87822a60fea8 is: 0.0
# The total score for guid ee8824bc-30be-4cca-a374-1085d0023096 is: 0.0
# The total score for guid d5c39deb-0fb5-41aa-b447-6d438f7e58c8 is: 3.0
# The total score for guid 82f0f508-b5d7-4614-bcea-ed5d2e300942 is: 4.0
# The total score for guid 5969390a-943c-4a89-8a60-70087ce1333a is: 0.0
# The total score for guid df95be20-cd99-443b-9aaa-4708639ee843 is: 0.0
# The total score for guid 7143aea9-ede0-4f72-8ea6-5227d89ec2c9 is: 18.0
# The total score for guid 7c919b52-925e-463e-99a0-242dc7dea8b2 is: 0.0
# The total score for guid 2a0f9d5b-ca82-4240-bfae-1e727ada2dba is: 0.0
# The total score for guid e9c4a692-c48c-47e6-af7e-3cfed6f82dad is: 0.0
# The total score for guid e63d967e-5cbb-4358-b926-57b9fb6c28fa is: 3.0
# The total score for guid 28320a35-6007-419a-ae50-9bf718b290e9 is: 0.0
# The total score for guid 8b81f5fd-20fd-4cfd-947b-2a32be16ac01 is: 0.0
# The total score for guid d5cdd9c6-c698-45b7-933b-34af00a35b2a is: 0.0
# The total score for guid 68a8ad5e-f728-4b1b-b45b-c0e213dfc419 is: 0.0
# The total score for guid 8a46a8e9-d0ef-4ee6-97c3-c5f01777071a is: 0.0
# The total score for guid 9e408bb5-61e0-47da-8fe5-11695f263265 is: 0.0
# The total score for guid f2fb0120-8e95-4731-ba3c-7f5683adea4f is: 9.0
# The total score for guid 20ca4cb8-6a0f-498f-8a55-12cfa615ec69 is: 0.0
# The total score for guid 85d3d30b-c912-4518-9456-ed3115aef071 is: 0.0
# The total score for guid 45b5cca4-0577-4542-a2e3-4edd630fe1b9 is: 9.0
# The total score for guid c889d8a2-7afd-45a0-a000-5fc5e7e52f42 is: 0.0
# The total score for guid 1403e3ed-a37b-4245-a98b-fb0d04503cf7 is: 0.0
# The total score for guid cddaaf35-5fb5-4e94-abe4-a5ad102948b1 is: 0.0
# The total score for guid 1cd53fc0-5676-454d-8d3b-419f803579a6 is: 45.0
# The total score for guid 214bdafa-3afd-42a9-9b61-26173924dfaf is: 0.0
# The total score for guid 60d401ef-722a-421f-9ffb-7e666dd8ad9f is: 0.0
# The total score for guid 99f9ee4e-2106-485f-8047-06ffd60911bc is: 4.0
# The total score for guid c6e894a0-9d72-401a-8d5f-6aad7b901326 is: 0.0
# The total score for guid 93a5df51-2398-4400-9aa8-3374533affa5 is: 24.0
# The total score for guid 5db5f8aa-601e-4f00-89b1-534d24faf873 is: 3.0
# The total score for guid 594e2f8c-50b8-4eaf-b1cf-7e2d8c1cea74 is: 3.0
# The total score for guid 51894036-721f-40a5-8e79-395a13e1cce6 is: 0.0
# The total score for guid b039ad42-87fa-47ba-bcde-7373978599b9 is: 12.0
# The total score for guid 2400a39d-a6c4-422a-9640-81b7e54e5e84 is: 0.0
# The total score for guid a250e313-131e-483e-aa8f-f3390901a6cb is: 0.0
# The total score for guid a8b8fc58-b33a-4287-9c78-d75947936618 is: 7.0
# The total score for guid 1fab652e-07c1-4903-b3b6-f93aac236a3d is: 12.0
# The total score for guid 08e80dbd-12e9-4f76-b8e1-0ae587967ce4 is: 0.0
# The total score for guid a0b1b986-8bf9-422f-bf0b-e6ab6c1b9905 is: 0.0
# The total score for guid 9d28c392-6224-4226-ae43-15986c0cc968 is: 0.0
# The total score for guid 8cf456c0-eeca-476f-ac99-5b109b9d1515 is: 6.0
# The total score for guid 91302f0b-cd19-4df1-914a-38e4f54bb458 is: 10.0
# The total score for guid 3de5b7ee-2888-4ff7-96bc-c17da325264f is: 16.0
# The total score for guid dc7e9a25-c647-4c20-909b-13d1df44698a is: 0.0
# The total score for guid 4340e485-958b-41a5-b94a-49c290eb21d7 is: 0.0
# The total score for guid 5cba14e5-c5d2-4501-8348-8ee53ace9e9f is: 9.0
# The total score for guid 71acf38b-bdf6-437f-bc18-ab5cb6b26b14 is: 3.0
# The total score for guid d5c51f59-5b33-498a-aa24-3a1c2733af29 is: 0.0
# The total score for guid be3b52a1-f143-48dd-b00e-62f3cbc2cce8 is: 0.0
# The total score for guid 8915f06c-cc73-45e7-a3b1-cdff8bc3281c is: 2.0
# The total score for guid 1550d88a-d25f-4d14-8e4e-a176beda355f is: 0.0
# The total score for guid db395a8a-f2e2-42f9-b754-0d37aba9bcef is: 15.0
# The total score for guid c8fd7b41-90de-45e2-92a0-a08c0ea95518 is: 0.0
# The total score for guid 58654bb4-851e-49bd-a5e0-b4e32d663756 is: 0.0
# The total score for guid 785a4e72-a92f-4a7f-afe0-4ada8a98ce5c is: 0.0
# The total score for guid 11b87b05-6d1f-46d7-a39c-ba9e72f6e3d0 is: 2.0
# The total score for guid 0f7ad0f5-ca09-4a5a-8b5b-c5d04c6fa032 is: 0.0
# The total score for guid 73eb6fe9-9b5e-4157-b739-026943623adc is: 2.0
# The total score for guid e0003320-cc6d-4c1d-be6e-eebc6b878073 is: 0.0
# The total score for guid 02b23a35-7632-4596-8361-a2883a98bc7e is: 0.0
# The total score for guid adabe281-e8c3-4338-8dd9-cac1088fc990 is: 0.0
# The total score for guid f72768d0-18f9-4a04-bad3-82460a044043 is: 2.0
# The total score for guid 935dba0c-1c5f-435b-a284-d8906b80bc34 is: 0.0
# The total score for guid 769cd641-6679-4b76-8e8e-9a85c645d4f6 is: 0.0
# The total score for guid ca1c6fc1-12a3-4205-a73f-2f5df0fc7a52 is: 0.0
# The total score for guid f22d4bbb-14f2-49a0-b925-bf74c54ceb4b is: 10.0
# The total score for guid 303ca6ca-8742-47a1-ae39-c62438de4199 is: 0.0
# The total score for guid 822bf580-c1c2-4440-94dc-26039ec1f0a0 is: 6.0
# The total score for guid b668f770-f18f-43f3-94e7-662f4efc400b is: 0.0
# The total score for guid 990dae65-806d-4e3e-b29d-3d6994ce0392 is: 0.0
# The total score for guid e1f75031-137a-42e0-86fc-ce31e5651981 is: 0.0
# The total score for guid 1e2aba4d-ddcc-4fee-9dfe-dd7f27ca0efd is: 0.0
# The total score for guid 78ee0f3e-ef4f-4d2a-99f2-b0cba96dba6e is: 5.0
# The total score for guid 9dc6afb6-1c7b-4207-bb74-b7aa84fff949 is: 0.0
# The total score for guid 5529f01e-0393-467d-829d-e0c8082e8313 is: 0.0
# The total score for guid 4331c5f2-7077-4a9e-9a34-511b13ced7e1 is: 0.0
# The total score for guid 49b714ee-c7ca-412e-b4eb-d8dbecfd3c71 is: 0.0
# The total score for guid 48311e5b-6447-4eab-840c-465c6ecf72bf is: 3.0
# The total score for guid 43710d89-c46d-4230-b32a-c71b8f5b066f is: 0.0
# The total score for guid 368a9dc1-de3f-4f92-b53a-a05ccfb817a4 is: 4.0
# The total score for guid 7418eae8-c25a-423e-ad89-4e49cbf89f01 is: 2.0
# The total score for guid 4c86d997-4153-4ec3-86c6-8568d983824b is: 6.0
# The total score for guid fbdb1565-33b3-4857-95b6-1616de90b12d is: 0.0
# The total score for guid 3fbc48c5-462e-4727-9149-503a3202509b is: 0.0
# The total score for guid 384af12d-e3eb-4085-b4f1-e91cef4fa545 is: 0.0
# The total score for guid 7fbc2e32-9949-44c6-98e8-fe8a4087e792 is: 0.0
# The total score for guid c0e1fab2-ac48-437e-b0c4-835b8e324b13 is: 0.0
# The total score for guid b9d03395-3085-4b69-be36-fd49806414da is: 0.0
# The total score for guid 8c56074f-c44f-4b11-95c8-44001f34649e is: 0.0
# The total score for guid 3a345f4b-95f6-4248-bf72-74eeb2c118e7 is: 0.0
# The total score for guid d3064904-6fd3-4509-92ca-f716286520dd is: 33.0
# The total score for guid 67ab7b5b-82cd-43c5-9431-f0f7145b6af1 is: 0.0
# The total score for guid 97e523c5-037c-4aec-b4ec-856d61f813b0 is: 0.0
# The total score for guid a9a72a3b-70fd-46e4-b0e0-432b88bdf145 is: 14.0
# The total score for guid ded0e675-d989-49d1-8e69-ae4fe427fdf3 is: 0.0
# The total score for guid c33405d7-f60e-4c00-9fc3-497ba0f3a7a5 is: 0.0
# The total score for guid 590a3be6-ec60-4765-9c70-36b5b840cde2 is: 0.0
# The total score for guid 2ad3feb8-b61c-44be-a81b-6f732f33d226 is: 6.0
# The total score for guid 2e65b261-64d4-42d6-8223-01c2856fa9a5 is: 7.0
# The total score for guid da83090c-93e2-4a3d-b8e5-7c249304a933 is: 3.0
# The total score for guid c544e0a9-a412-42b0-bb67-d66575d7c03c is: 0.0
# The total score for guid 9ee21b04-6d9d-4d4d-b423-275799f22a7f is: 0.0
# The total score for guid d10765f9-428c-4e36-9ae1-5c41259d3358 is: 0.0
# The total score for guid b7d92b76-25ef-4093-81ac-d6a19cc84a66 is: 0.0
# The total score for guid 4f05c7c8-777e-48ee-aac6-d006b2e4ea30 is: 0.0
# The total score for guid 85720ba1-9689-4dc6-a154-d01526a69fe9 is: 0.0
# The total score for guid ada56170-3a3a-4056-a950-154ef9e65429 is: 2.0
# The total score for guid 467ba16c-eb12-4b48-ac82-694f5353d261 is: 2.0
# The total score for guid b8717c30-4fad-404d-aa8e-8b0502540c64 is: 0.0
# The total score for guid 17ae472b-e0bc-4c1b-a4af-1b169206e75e is: 0.0
# The total score for guid 047a5a15-39d6-40d1-b65f-381d2ed7c72c is: 0.0
# The total score for guid 3ffada58-1fde-4516-8a6c-7c6bfebf22b5 is: 0.0
# The total score for guid 25379554-fbc3-4efd-a9b1-ba35b8e252c9 is: 0.0
# The total score for guid 6032967e-ed37-474f-8993-aa2dc0289059 is: 0.0
# The total score for guid 2d5f32c6-fd5f-47bd-82cc-5cbb4ea1af88 is: 3.0
# The total score for guid 0b21afe5-a642-470a-9d24-6053691d3b91 is: 6.0
# The total score for guid 1a16a25e-7758-4f3a-ae18-bc21179ccbc8 is: 0.0
# The total score for guid 6e361a80-396f-4161-ae67-a175b5689653 is: 0.0
# The total score for guid 879ffc2f-c4ed-4d0b-8ac3-08d28cc82cbb is: 5.0
# The total score for guid 17e1f2b6-00f7-4080-b82a-68d32710a676 is: 0.0
# The total score for guid fd7aea18-17bd-4f34-86d1-c59d172e3fac is: 3.0
# The total score for guid 83a26e79-e1e3-490c-a9b2-4a71a6c282ca is: 0.0
# The total score for guid 32c3ca38-b0c9-4a1c-b9f4-a8cf7e24fb97 is: 0.0
# The total score for guid 1a2c5a30-4c2d-4471-a7cf-4f9207837353 is: 0.0
# The total score for guid 9dcb58ab-7635-4542-8447-ef6cdd538691 is: 0.0
# The total score for guid 3c13157f-db0c-420a-9b15-89a9d6bd159a is: 22.0
# The total score for guid 224a1a5c-411d-4f1d-8c5f-6ba8b76b2a06 is: 0.0
# The total score for guid 9c6ab88e-66a0-4271-a30f-302c43a3fdec is: 0.0
# The total score for guid c17d2f52-d737-4bda-9a15-f9ceaee5645c is: 0.0
# The total score for guid 94019ef3-ced9-430a-bc8b-16a8145d6f7d is: 0.0
# The total score for guid 61cd0ac4-c83c-449c-9ea7-778786d8447c is: 0.0
# The total score for guid 5b1be8ab-f9e9-489e-81d9-99eae78fd6fe is: 0.0
# The total score for guid 2a957603-a921-46ac-a313-5fb96d9e47b8 is: 0.0
# The total score for guid 8a8f438d-4d91-4894-89dc-a4c5381e4a27 is: 6.0
# The total score for guid 42e06b28-c3f6-4c23-850a-72a6c8fa5fd3 is: 0.0
# The total score for guid 4f295f6b-6f69-4738-99c7-b31d1f1d9192 is: 0.0
# The total score for guid 1386edd5-7b53-4577-a90d-604a829e75b4 is: 0.0
# The total score for guid 0ce968b2-c7f2-4304-a814-dd4af7b5e9d2 is: 4.0
# The total score for guid 3a284927-8087-437a-b3c2-8085f941805a is: 12.0
# The total score for guid 8b2b48e6-8c73-4585-938c-2127f4fd6812 is: 12.0
# The total score for guid 3e2893d0-00dc-4fea-b169-31ed16a63015 is: 0.0
# The total score for guid 8b818a61-fb65-47e9-8883-3bdd5e90e361 is: 2.0
# The total score for guid 0575d230-4e2f-43ec-baa7-b3e7dfa6c83c is: 0.0
# The total score for guid a2e3b9d0-0b3c-4325-97c1-f26bf0fc73d6 is: 0.0
# The total score for guid e1c6cb2a-f558-48dd-831f-0e34d1d73f9c is: 2.0
# The total score for guid 3b693117-f240-4acf-a4ca-ccd05d32c528 is: 0.0
# The total score for guid 8e7a25f2-2169-47d9-90d2-671d35822721 is: 0.0
# The total score for guid fa9fee6e-498e-45dc-b780-7aec729f6b85 is: 0.0
# The total score for guid d2af39e8-4a27-4110-9935-3349b8a7a8e8 is: 5.0
# The total score for guid 79d207d9-dc98-48f4-9843-bef41a478af5 is: 9.0
# The total score for guid f26a284b-a141-4c72-822f-2c3099359d32 is: 0.0
# The total score for guid e8c16c0e-e1f8-4e53-a2bd-aa46124e295f is: 0.0
# The total score for guid 723e60dd-e078-423e-a04e-00b1453438ab is: 0.0
# The total score for guid 717e3eb9-d55d-47e6-add7-d920bb961443 is: 13.0
# The total score for guid fac35d28-fcdb-461c-ab23-005297867cc3 is: 0.0
# The total score for guid 69659f33-f02d-4482-b52c-d5f88cc7e665 is: 0.0
# The total score for guid bd9ff779-1b2a-4877-9344-d2e6a3fa029d is: 0.0
# The total score for guid 3e7a0328-d52b-4050-aaba-470a50e2c09b is: 6.0
# The total score for guid 453d4bd2-7aca-4c5c-8230-c07b170a8636 is: 7.0
# The total score for guid d75bb652-51c6-4598-8d17-eb49eeb1e251 is: 6.0
# The total score for guid 63a821bf-56f4-41eb-bfd7-d3a3934b7f23 is: 0.0
# The total score for guid 6629cd91-f5d7-4095-85ae-eea331711331 is: 0.0
# The total score for guid 9b00e031-786f-4734-adb5-0b2e06bf9df5 is: 0.0
# The total score for guid 643fe55b-6d96-4a1e-9d1f-9d9055eee6b3 is: 0.0
# The total score for guid 4679cbe6-c370-421e-a188-13fb8fbe85f1 is: 81.0
# The total score for guid 81d4691e-7f50-4fa4-b1f6-f661be9203a9 is: 0.0
# The total score for guid 28f2a8d4-dc40-4608-b874-4e6439a8b264 is: 0.0
# The total score for guid 11378006-9dc3-4d34-b130-c4f06ba03cc7 is: 0.0
# The total score for guid 61168258-3577-4334-8f5e-152ce99e2f28 is: 0.0
# The total score for guid ff4bbd88-d9bb-4f58-9d3a-9b19de2256dd is: 0.0
# The total score for guid c4ae30f3-315b-4b78-b214-613e60f01438 is: 12.0
# The total score for guid 43509b00-25f1-4298-a2ec-6f50e5f41756 is: 0.0
# The total score for guid 862a0b3f-26e5-437f-8137-d01fa0363c1e is: 12.0
# The total score for guid a6afc0ab-cc27-4494-9838-8b2685579571 is: 2.0
# The total score for guid 2c31f9ae-7e4a-41c1-9c1a-77e0adea3924 is: 2.0
# The total score for guid a8a36b44-42fb-4dfa-85b4-82be939a7b93 is: 0.0
# The total score for guid 99290a2e-b761-4729-9e7b-fbfe6e14ec07 is: 0.0
# The total score for guid d8e79fff-7811-4c8d-b7df-4c154b50e589 is: 0.0
# The total score for guid ac608bfd-3aa6-4758-ae8e-c04709440ed0 is: 0.0
# The total score for guid 59b34aad-6c8d-4fcf-b9bc-498a6a4dee72 is: 0.0
# The total score for guid f5f3d290-3d39-4667-855e-28d933eb0b2f is: 0.0
# The total score for guid 6b67d369-dc5b-4700-9487-c75ae590ebbb is: 3.0
# The total score for guid e76556d5-ec2f-44ca-ab50-6f95da971e37 is: 0.0
# The total score for guid fdbf01a0-0dec-42de-bbc8-f3d6aa0e4a0e is: 0.0
# The total score for guid 9d0d8640-c798-48d9-8616-d930b11be239 is: 0.0
# The total score for guid 53cfd06f-a02d-4254-9576-0c91ab7a0738 is: 0.0
# The total score for guid 4e380445-ff40-4113-af4a-ab456a1a99ee is: 18.0
# The total score for guid c59dd68c-5f6d-40c7-ae7c-1a251d0b8ef5 is: 0.0
# The total score for guid c717e7c2-f00a-4a62-aa0e-324a19f71446 is: 0.0
# The total score for guid 9487a3ec-0c63-4f53-9ecc-1863949901b6 is: 0.0
# The total score for guid a20aabd6-8d86-4638-8398-f675ac8cd218 is: 0.0
# The total score for guid 2d5562f1-178b-4054-8959-7b094b2117b7 is: 0.0
# The total score for guid 32b93689-d9d1-456c-8682-b632e36f9c72 is: 0.0
# The total score for guid 57f61165-a665-4bb4-a62b-9377ffdde624 is: 0.0
# The total score for guid 7b535634-ca65-4b5d-b84b-df7c2451acfa is: 0.0
# The total score for guid 455a8cce-42b5-4eab-8b5c-aeb0957c88a4 is: 0.0
# The total score for guid b9cc243e-2e76-4a45-a181-251f0d1b735f is: 6.0
# The total score for guid 428a6707-05f9-46ab-b17e-628462222a4a is: 2.0
# The total score for guid 797d32e0-2ca9-4105-891c-b745c0f3aa38 is: 6.0
# The total score for guid 615664e6-6b9a-4149-8ea5-7aa54eb13619 is: 0.0
# The total score for guid 5cee304d-4927-43e7-950a-fb590231f086 is: 0.0
# The total score for guid d49a2ccd-bd8f-4615-b3bc-fc714abd49f3 is: 0.0
# The total score for guid b6432226-7d5d-4245-8d59-e7f23f2e5152 is: 0.0
# The total score for guid 4156d9a4-28e9-401e-91b8-aaa543cdb970 is: 0.0
# The total score for guid 6ecacd87-e4c2-42cc-9c01-4d05baac94f4 is: 0.0
# The total score for guid b4018edb-ee39-4b5d-ae9e-b1cbedcb25ea is: 0.0
# The total score for guid da5f730d-6880-450f-87f0-63692e39676e is: 0.0
# The total score for guid 5ff878fc-4ed3-4ff4-8b97-9f80f0aa2440 is: 0.0
# The total score for guid 5c89d4ab-7783-4974-a168-3133b34c03ec is: 0.0
# The total score for guid 8fe75f17-d7d1-412b-8212-98b8f42c270f is: 2.0
# The total score for guid 30d50454-f571-4789-81b7-4a6a05677515 is: 0.0
# The total score for guid 36aa814a-8080-4e2b-8127-5a8f77518321 is: 0.0
# The total score for guid 100e5d44-715f-47e3-9dd8-534e0a2ce226 is: 6.0
# The total score for guid d75973cc-c4a6-4a33-8d8c-96552bc0d616 is: 2.0
# The total score for guid 97f8159a-2585-431e-9f70-9acfdf3d22dc is: 0.0
# The total score for guid 368d6470-c8b5-402b-a8cb-e92f1a0afa78 is: 0.0
# The total score for guid 77e6c2e9-2ee9-4f40-8fe3-052b194a5e74 is: 0.0
# The total score for guid 93dc3300-d1aa-4a14-94f4-de5096b38c2a is: 0.0
# The total score for guid 7ae3b040-72c4-421d-9357-f7cfa7f8ea8e is: 0.0
# The total score for guid 45e0742d-d9b1-4ebc-a6c7-f43df7c8cce2 is: 0.0
# The total score for guid 3b4d0ceb-fe17-46ee-b39e-5f59637f2bac is: 9.0
# The total score for guid 23be6c49-5240-4fec-aba4-bc1f7898dd31 is: 0.0
# The total score for guid dcfed42b-bcb3-4272-a6c9-9ef2289f1a2d is: 11.0
# The total score for guid fba03c0b-d360-4219-9e5e-fce2335962b7 is: 0.0
# The total score for guid 666fcad8-b9f1-42b0-8a3b-08dd5fbb0da3 is: 0.0
# The total score for guid cee15890-9d24-45e6-b8cb-54c2f0feeecc is: 6.0
# The total score for guid 25e2c56c-39ad-4462-9a89-4fb6c32f1469 is: 0.0
# The total score for guid 6693e39a-753b-4dd6-8405-dd21647f1887 is: 10.0
# The total score for guid 75ba319f-b397-4a23-9e3b-d02a68fcb4b4 is: 0.0
# The total score for guid c87106d6-c14e-457d-8179-0de9e734d14a is: 0.0
# The total score for guid e518f3ad-2886-4cf0-9dad-75fe548b5898 is: 0.0
# The total score for guid 7de35a34-b774-4605-87b0-7a8d8d40bbce is: 9.0
# The total score for guid 24fc3548-068e-490e-8205-85db3913f7ff is: 0.0
# The total score for guid 84e7a7da-2070-49d5-8e50-c063e9893a7c is: 0.0
# The total score for guid f5be321c-4b32-400e-b03f-40b347e9601e is: 0.0
# The total score for guid 5c092d05-0733-4127-978e-65a989369e7b is: 0.0
# The total score for guid e34279e4-1a48-4a28-a0e5-44f8351aea3b is: 5.0
# The total score for guid 994d7713-8631-4550-ad41-f533ef137ccf is: 0.0
# The total score for guid 1a5815ed-7a12-4dbc-8f48-b3a21ad9d0a3 is: 0.0
# The total score for guid 2f75e20d-e316-45cf-ac65-3ecb3b12f3d5 is: 0.0
# The total score for guid a324ee8a-a07b-45b3-a79e-0498c77e0e1f is: 6.0
# The total score for guid cf780e77-8026-4a86-b6a8-14f2e2219762 is: 3.0
# The total score for guid 4b350d6f-c5fa-4739-8e70-091e918e7973 is: 0.0
# The total score for guid 5afe5ae3-6dbd-4d9c-a34b-dab33e6026d0 is: 12.0
# The total score for guid 3d17dd12-1fae-4044-ae95-f31b16fe0672 is: 0.0
# The total score for guid 0b8e8090-5f7d-4a42-9b36-13b6c562a36f is: 0.0
# The total score for guid 154700e6-8f30-49e1-b07a-4a8e4c6e6592 is: 0.0
# The total score for guid 5e9a76f1-74c7-4883-be3f-8087e72ce33b is: 0.0
# The total score for guid b8f6e0f1-7acd-4134-a662-30e49c04c5b8 is: 0.0
# The total score for guid 669df770-2070-492c-ae14-00f698f2f3f7 is: 0.0
# The total score for guid 78a29f47-8250-41fd-8279-87863a518bae is: 3.0
# The total score for guid fdea9901-c23d-46ba-a107-7a0eee51983f is: 16.0
# The total score for guid 85790aee-6af8-4094-8795-fd6b9a49dd3c is: 0.0
# The total score for guid dec78e68-9811-463b-a054-48d5550ecc0b is: 0.0
# The total score for guid c99de783-0a8a-43af-af72-a9a7165ab66a is: 3.0
# The total score for guid 19961e94-fc97-4234-93b4-dc699764c5f3 is: 0.0
# The total score for guid fa428426-2f16-4b0b-aa68-ba719052c63e is: 0.0
# The total score for guid 59d91158-8d75-4778-bfdc-8833b1fd803f is: 23.0
# The total score for guid 17c49cb6-995e-4da7-ad93-d31baa608017 is: 7.0
# The total score for guid 093f63bf-6a91-4384-bfea-6c5fff9f6df2 is: 0.0
# The total score for guid e6a6b0d5-1b33-47b9-be9b-7000cd0c2b22 is: 0.0
# The total score for guid 5959fddf-10cd-471b-af72-ae5a3bf4ef38 is: 0.0
# The total score for guid 53e37cd9-493d-49bc-bc3b-72d74a1a6b96 is: 0.0
# The total score for guid 135f69cd-aad8-4e9f-9697-4bb357921c72 is: 16.0
# The total score for guid b4e1e006-96d9-4f7e-85c7-c4a33b63d347 is: 0.0
# The total score for guid 2c070130-02c2-4984-944e-437dc422d416 is: 0.0
# The total score for guid 0d229044-0223-4a21-a553-36f7a0db7cbc is: 9.0
# The total score for guid 85eff3d3-a172-496f-9f2d-d71bb6a1904d is: 0.0
# The total score for guid 6e401c1f-5603-4629-b10a-abcbe3222768 is: 0.0
# The total score for guid 7bdf1db1-c3a3-4085-8e5b-4253dd523d70 is: 0.0
# The total score for guid 58a63dee-8a76-47d6-8cac-aa132f846cdb is: 2.0
# The total score for guid 026ac4bf-148d-4422-9ede-52dd04fe8d78 is: 0.0
# The total score for guid f8bb4726-8a22-4f1e-b223-58d2ecf96b24 is: 0.0
# The total score for guid 29d54c52-5f17-47f0-b9d5-1b4cc5fb4d3f is: 15.0
# The total score for guid ed7fd097-f945-499a-a30c-5f92915bd55e is: 3.0
# The total score for guid 11d9a1ef-7c3e-47ba-a052-0e900621b689 is: 0.0
# The total score for guid 72176ffe-0463-4f6e-8556-eddd4a3001a0 is: 0.0
# The total score for guid efa7edd6-4f64-4ba9-b3d4-89c0d60db8c0 is: 5.0
# The total score for guid c0e0c8bb-ba97-4ab6-b628-19ecc5fa1d8a is: 2.0
# The total score for guid 54b13d85-dcd6-4469-8c9f-315a5cd4749e is: 0.0
# The total score for guid 576fec3d-fa75-4219-bd90-00b092b50f6a is: 6.0
# The total score for guid 8c8eb8e4-708e-461b-9c4d-9cb63cf1c648 is: 0.0
# The total score for guid ae12a976-3703-481a-80a1-c951f3f56004 is: 0.0
# The total score for guid b7345c5b-b046-4265-9fa1-009d06e6e0ff is: 4.0
# The total score for guid b2064a64-388d-4c6f-98fd-e5e8a3208b80 is: 6.0
# The total score for guid fabd820f-a764-49d2-9572-89bda4eab77b is: 0.0
# The total score for guid 9813e0d7-032b-4d6b-804f-c8422680ad5a is: 3.0
# The total score for guid 6c689b9d-6c7a-4900-8c9d-3dfa13d90629 is: 0.0
# The total score for guid 9a7dd328-dddc-49fb-9116-c46c18d4c708 is: 0.0
# The total score for guid b2084c42-1afd-44e9-ba37-52bd267b6c76 is: 0.0
# The total score for guid 58c22569-fbcc-4def-86de-bf0d8f3ed18d is: 8.0
# The total score for guid d26e3c17-627b-496f-a518-defff40a9d46 is: 0.0
# The total score for guid 1464fa20-a4be-42bd-aff9-7cde01fc41d4 is: 0.0
# The total score for guid 3528d6ae-9620-4551-bf46-56a278fd43e9 is: 3.0
# The total score for guid f0eb33cd-ed32-4dff-911d-efdaa29a1190 is: 6.0
# The total score for guid fa819bbb-558c-4470-90ad-5b3c277b18b1 is: 0.0
# The total score for guid a6c4226c-c4c9-433f-ab37-562581b3c66e is: 2.0
# The total score for guid beab0a27-94e8-4e2a-9c86-e92673e2c6f3 is: 0.0
# The total score for guid 08e192a5-0853-4b50-88d4-ea1a50a433fd is: 0.0
# The total score for guid e555fcab-2b80-4b7d-a896-dc322995e765 is: 0.0
# The total score for guid 7702322b-848e-4409-9202-2e72fbf4173a is: 0.0
# The total score for guid df9f77f1-faa2-4944-8d35-c9683eddd049 is: 0.0
# The total score for guid 7c70349e-5839-44f9-ab63-3b9a9a133f8d is: 6.0
# The total score for guid ff8d5f44-d16f-47fb-a6de-3752c9034067 is: 0.0
# The total score for guid ac187f07-0433-4a3d-9c85-a27dd26d5746 is: 0.0
# The total score for guid d08db9eb-b139-4d09-89b1-039f5b8c3365 is: 0.0
# The total score for guid d019e519-cd43-4a7c-b084-5a93c325b8ed is: 0.0
# The total score for guid 3360ce04-7753-4c52-8ea7-4f762945e225 is: 0.0
# The total score for guid bcc0c01d-f3d9-4da2-8ea6-a5cb200f1ea4 is: 0.0
# The total score for guid b9941c98-4a4b-4304-b3af-3473c14980b0 is: 0.0
# The total score for guid 0f0a8ddc-ffe2-405f-bd08-62aff2c6f601 is: 0.0
# The total score for guid 5c08ce9d-0d90-491d-969d-238c656a2cac is: 0.0
# The total score for guid 53eae262-8914-4480-a1a2-8e7ced88d011 is: 0.0
# The total score for guid 8256c705-8614-40cc-a503-31feade443fd is: 0.0
# The total score for guid 6bbf45fa-3963-4ffe-946b-ec916b044604 is: 0.0
# The total score for guid 09be809e-d9f8-4303-b6b7-a147977473e2 is: 10.0
# The total score for guid 4d8a6fd3-db31-4701-8133-3195e8e64e6b is: 6.0
# The total score for guid 1f27b80f-3736-470a-b5d5-4cc460973bdb is: 0.0
# The total score for guid 77fa5ad0-0d3e-4828-a9f7-d396574f4e77 is: 5.0
# The total score for guid c9eebebf-41f0-47bd-adc1-64e5987cef53 is: 0.0
# The total score for guid 90beb700-950b-459a-bc5b-a85d2ac6145a is: 13.0
# The total score for guid a810d827-ec19-4a24-95da-745262ce70b6 is: 0.0
# The total score for guid d60ca7c5-9b32-4cb5-883f-c5db79583d1e is: 26.0
# The total score for guid e19370a1-c7a8-4712-ae7a-ad99d08e8842 is: 12.0
# The total score for guid 6c985c47-88ad-47ea-98c3-39422a56293b is: 0.0
# The total score for guid 507ce487-c53e-432d-847b-576a19adf40a is: 2.0
# The total score for guid 29e60ae3-3d0d-4b8f-90bf-7547e07c7d81 is: 0.0
# The total score for guid 1f188394-9a4d-49ef-9c2e-8facc91b776c is: 0.0
# The total score for guid 6362d37c-1ac8-4ef2-961e-35a5bffc4c01 is: 6.0
# The total score for guid e5abcb14-ce01-40ee-aa0f-e413d86a5365 is: 0.0
# The total score for guid f48e33fa-4649-49b4-acd3-8a2df707da61 is: 0.0
# The total score for guid f1160bab-082e-4065-9d24-a9abf75568c2 is: 0.0
# The total score for guid 9f7d31d9-e550-4e96-9107-2c5d2fe1cf2e is: 9.0
# The total score for guid ee9a4445-f203-45b6-a250-02d038b1d84c is: 23.0
# The total score for guid ba460c67-00b1-401e-8ea2-75a220ac354d is: 0.0
# The total score for guid 12b95859-94b5-4670-a6f9-6427ebf01bff is: 0.0
# The total score for guid 26bc4ef8-43c1-487a-ac3d-3d5faaead6ab is: 6.0
# The total score for guid abe5098f-01c9-4ce6-a49d-026ce9674d59 is: 0.0
# The total score for guid 6904e350-8f0b-4d71-9493-205688bf3e42 is: 0.0
# The total score for guid b9ba4e06-52d2-45bd-926c-d4698e876977 is: 2.0
# The total score for guid f2abc22f-6a1d-4502-bf9b-41daa3e8c77e is: 7.0
# The total score for guid 36417bde-a426-4097-9d49-bfebb7660a7c is: 2.0
# The total score for guid 90d0fd86-c3cf-4e16-b1db-1478b37f88c4 is: 0.0
# The total score for guid 03aec8c5-710b-4c14-a38c-7e8bf316fe88 is: 0.0
# The total score for guid 4f984206-d8b2-4653-90ab-9449f19e5f65 is: 0.0
# The total score for guid 5ad67951-77a0-433d-9c12-39c374e82b68 is: 0.0
# The total score for guid 1fec50f6-4cd1-4507-88de-be48d21801ae is: 0.0
# The total score for guid f42cf2f8-c9a2-4d9c-a20a-1405efb21141 is: 18.0
# The total score for guid 2638b269-2152-4f66-afe1-64c51b76b718 is: 0.0
# The total score for guid 665d47fa-c933-448f-a682-98cf91acdc66 is: 0.0
# The total score for guid d248d033-1cfd-4b30-9716-ac8e3e6aae3c is: 0.0
# Total for this vendor 1218.0
# fini
